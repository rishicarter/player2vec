# %%
import pandas as pd
import os

# %%
def fetch_players_data(filepath):
    temp_df=pd.read_hdf(filepath,'all_players')
    return temp_df


# Class driver
class player2vec_data:
    filepath=os.path.abspath(os.path.join('Wyscout','final_results_allplayers.h5'))
    player_data_df=None
    selected_player=""
    def __init__(self):
        self.player_data_df=fetch_players_data(self.filepath)
    def get_player_names(self):
        return self.player_data_df['player_name'].unique()
    def get_filtered_list(self,name):
        self.selected_player=name
        return self.player_data_df[self.player_data_df.player_name.str.contains(str(name))]
    def get

# %%
test=player2vec_data()
test.get_player_names()
# Out:
# ['T. Alderweireld',
#  'J. Vertonghen',
#  'C. Eriksen',
#  'R. Klavan',
#  'N. Moisander',
#  'J. Guðmunds\xadson',
#  'Marcelo',
#  'E. Pieters',
#  'J. Willems',
#  'K. Strootman',
#  'G. Wijnaldum',
#  'M. Depay',
#  'D. Mertens',
#  'O. Toivonen',
#  'T. Kongolo',
#  'B. Martins Indi',
#  'J. Guidetti',
#  'J. Gouweleeuw',
#  'D. Janmaat',
#  'R. van La Parra',
#  'F. Đuričić',
#  'J. Vuković',
#  'R. Rosales',
#  'L. Fer',
#  'M. van der Hoorn',
#  'Cuco Martina',
#  'V. van Dijk',
#  'Suk Hyun-Jun',
#  'D. Tadić',
#  'B. Nuytinck',
#  'P. van Aanholt',
#  'D. Pröpper',
#  'M. de Roon',
#  'M. Yoshida',
#  'K. Tete',
#  'Jordi Alba',
#  'Barragán',
#  'A. Rami',
#  'Víctor Ruíz',
#  'Bruno Saltor',
#  'É. Banega',
#  'Juan Bernat',
#  'Canales',
#  'Dani Parejo',
#  'Portu',
#  'Aduriz',
#  'P. Piatti',
#  'Albiol',
#  'Nacho',
#  'Sergio Ramos',
#  'Pedro Mendes',
#  'R. Varane',
#  'José Callejón',
#  'Á. di María',
#  'Granero',
#  'S. Khedira',
#  'M. Özil',
#  'N. Şahin',
#  'K. Benzema',
#  'Cristiano Ronaldo',
#  'G. Higuaín',
#  'Álvaro Morata',
#  'Juanfran',
#  'Joselu',
#  'Dani Alves',
#  'Bartra',
#  'Sergi Gómez',
#  'Montoya',
#  'Muniesa',
#  'Piqué',
#  'Rafinha',
#  'Thiago Alcântara',
#  'Sergio Busquets',
#  'Sergi Roberto',
#  'Deulofeu',
#  'Fàbregas',
#  'Kiko Femenía',
#  'Iniesta',
#  'Cristian Tello',
#  'L. Messi',
#  'Pedro',
#  'A. Sánchez',
#  'A. Guardado',
#  'Ramalho',
#  'Saborit',
#  'San José',
#  'Ander Herrera',
#  'Iturraspe',
#  'Javi Martínez',
#  'Susaeta',
#  'De Marcos',
#  'Ibai Gómez',
#  'João Miranda',
#  'Filipe Luis',
#  'Javi Manquillo',
#  'Gabi',
#  'Koke',
#  'R. Falcao',
#  'Adrián López',
#  'Coke',
#  'F. Fazio',
#  'Luna',
#  'Alexis',
#  'Juan Cala',
#  'Campaña',
#  'Jesús Navas',
#  'D. Perotti',
#  'I. Rakitić',
#  'Luis Alberto',
#  'Sergio Postigo',
#  'Raúl García',
#  'Timor',
#  'F. Lejeune',
#  'M. Musacchio',
#  'Mario',
#  'C. Zapata',
#  'Jaume Costa',
#  'J. de Guzmán',
#  'M. Wakaso',
#  'Trigueros',
#  'Borja Valero',
#  'Nacho Monreal',
#  'Isco',
#  'Recio',
#  'Joaquín',
#  'Portillo',
#  'Juanmi',
#  'S. Rondón',
#  'Beñat',
#  'Jorge Molina',
#  'Ramis',
#  'Chory Castro',
#  'Tomás Pina',
#  'De La Bella',
#  'Íñigo Martínez',
#  'Markel Bergara',
#  'Illarramendi',
#  'Xabi Prieto',
#  'Zurutuza',
#  'A. Griezmann',
#  'Bernardo Espinosa',
#  'Álvaro González',
#  'P. Diop',
#  'Adrián',
#  'K. Babacar',
#  'C. Stuani',
#  'Balenziaga',
#  'Z. Feddal',
#  'H. Moreno',
#  'Víctor Sánchez',
#  'Philippe Coutinho',
#  'Sergi Darder',
#  'Javi López',
#  'Sergio García',
#  'Hugo Mallo',
#  'Raúl Navas',
#  'Iago Aspas',
#  'F. Orellana',
#  'M. Iturra',
#  'Kike García',
#  'Borja Bastón',
#  'L. Cabrera',
#  'Pedro López',
#  'Vicente Iborra',
#  'N. El Zhar',
#  'Roger',
#  'Gálvez',
#  'D. Suárez',
#  'M. Lacen',
#  'Rubén Pérez',
#  'Pedro León',
#  'Pablo Sarabia',
#  'Sergi Enrich',
#  'J. Murillo',
#  'Ander Capa',
#  'Ángel',
#  'Míchel',
#  'Ximo Navarro',
#  'Borja García',
#  'David López',
#  'Javi Fuego',
#  'Diego Costa',
#  'Laguardia',
#  'Juanpe',
#  'Javi Castellano',
#  'Vicente Gómez',
#  'Roque Mesa',
#  'Dani Castellano',
#  'Vitolo',
#  'Jonathan Viera',
#  'Jonny',
#  'Yuri Berchiche',
#  'Saúl',
#  'Lucas Vázquez',
#  'Daniel Carvajal',
#  'Pedro Mosquera',
#  'D. Cheryshev',
#  'A. Szymanowski',
#  'David Juncà',
#  'Iván Balliu',
#  'Arbilla',
#  'José Gayá',
#  'Alberto Moreno',
#  'Jozabed',
#  'Tana',
#  'Mariano Díaz',
#  'Omar Ramos',
#  'Sergio León',
#  'A. Nyom',
#  'Mikel Rico',
#  'Toño',
#  'Gerard Moreno',
#  'Luis Hernández',
#  'Guerrero',
#  'Dani García',
#  'Sandro',
#  'F. Andone',
#  'Aday',
#  'Zaldúa',
#  'Bustinza',
#  'Eraso',
#  'Albentosa',
#  'Manu García',
#  'Léo Baptistão',
#  'K. Gibbs',
#  'L. Koscielny',
#  'Miquel',
#  'B. Sagna',
#  'T. Vermaelen',
#  'A. Oxlade-Chamberlain',
#  'A. Ramsey',
#  'J. Wilshere',
#  'T. Walcott',
#  'R. Bertrand',
#  'Oriol Romeu',
#  'S. Kalou',
#  'R. Lukaku',
#  'Juan Mata',
#  'Fernando Torres',
#  'J. Evans',
#  'P. Jones',
#  'M. Keane',
#  'Rafael',
#  'T. Cleverley',
#  'D. Fletcher',
#  'J. Lingard',
#  'P. Pogba',
#  'A. Valencia',
#  'A. Young',
#  'J. Hernández',
#  'W. Rooney',
#  'D. Welbeck',
#  'M. Kelly',
#  'J. Henderson',
#  'Lucas Leiva',
#  'J. Shelvey',
#  'L. Suárez',
#  'P. Dummett',
#  'M. Abeid',
#  'Y. Cabaye',
#  'D. Gosling',
#  'C. Clark',
#  'M. Albrighton',
#  'Marcos Alonso',
#  'D. Stephens',
#  'N. Redmond',
#  'J. Cork',
#  'J. Stephens',
#  'M. Schneiderlin',
#  'J. Ward-Prowse',
#  'Iago Falqué',
#  'S. Dann',
#  'M. Olsson',
#  "S. N'Zonzi",
#  'J. Ward',
#  'L. Baines',
#  'S. Coleman',
#  'S. Duffy',
#  'P. Jagielka',
#  'B. Assou-Ekotto',
#  'K. Walker',
#  'G. Bale',
#  'A. Lennon',
#  'J. Livermore',
#  'L. Modrić',
#  'A. Pritchard',
#  'J. Defoe',
#  'A. Kolarov',
#  'V. Kompany',
#  'K. Rekik',
#  'S. Savić',
#  'P. Zabaleta',
#  'G. Barry',
#  'David Silva',
#  'J. Milner',
#  'S. Agüero',
#  'M. Balotelli',
#  'E. Džeko',
#  'K. Naughton',
#  'A. Surman',
#  'C. Dawson',
#  'C. Brunt',
#  'S. Long',
#  'G. Murray',
#  'W. Zaha',
#  'S. Ward',
#  'A. Smith',
#  'F. Delph',
#  'A. Townsend',
#  'A. King',
#  'J. Schlupp',
#  'P. Bardsley',
#  'J. McClean',
#  'S. Sessègnon',
#  'W. Reid',
#  'J. Tomkins',
#  'M. Noble',
#  'A. Cresswell',
#  'M. Diamé',
#  'J. McArthur',
#  'V. Moses',
#  'F. Di Santo',
#  'M. Lowton',
#  'H. Maguire',
#  'M. Antonio',
#  'H. Kane',
#  'R. Shawcross',
#  'P. Crouch',
#  'J. Lascelles',
#  'A. Mariappa',
#  'J. Hogg',
#  'T. Deeney',
#  'A. Westwood',
#  'B. Mee',
#  'K. Trippier',
#  'C. Austin',
#  'J. Rodriguez',
#  'J. Stanislas',
#  'T. Carroll',
#  'J. Hendrick',
#  'W. Hughes',
#  'A. Taarabt',
#  'L. Dunk',
#  'A. Barnes',
#  'S. Vokes',
#  'C. Wood',
#  'M. Ritchie',
#  'S. Cook',
#  'S. Francis',
#  'S. Malone',
#  'H. Arter',
#  'C. Daniels',
#  'M. Pugh',
#  'J. Stones',
#  'M. Phillips',
#  'T. Ince',
#  'J. Tarkowski',
#  'R. Brady',
#  'J. King',
#  'J. Ibe',
#  'K. Long',
#  'S. Clucas',
#  'A. Gray',
#  'Suso',
#  'R. Sterling',
#  'T. Smith',
#  'M. Veljkovic',
#  'M. Dembélé',
#  'M. Trotta',
#  'S. Arfield',
#  'C. Wilson',
#  'D. Gayle',
#  'J. Vardy',
#  'D. Alli',
#  'S. Papastathopoulos',
#  'S. Prödl',
#  'P. Bargfrede',
#  'Z. Junuzović',
#  'M. Arnautović',
#  'N. Füllkrug',
#  'A. Hunt',
#  'H. Badstuber',
#  'J. Boateng',
#  'Luiz Gustavo',
#  'T. Kroos',
#  'D. Alaba',
#  'F. Ribéry',
#  'A. Robben',
#  'M. Gómez',
#  'T. Müller',
#  'N. Petersen',
#  'C. Molinaro',
#  'A. Rüdiger',
#  'G. Sakai',
#  'C. Gentner',
#  'M. Harnik',
#  'V. Ibišević',
#  'S. Okazaki',
#  'G. Castro',
#  'D. da Costa',
#  'B. Oczipka',
#  'Ö. Toprak',
#  'L. Bender',
#  'K. Bellarabi',
#  'A. Schürrle',
#  'M. Hummels',
#  'C. Löwe',
#  'Ł. Piszczek',
#  'M. Schmelzer',
#  'N. Subotić',
#  'M. Bakalorz',
#  'S. Bender',
#  'M. Götze',
#  'İ. Gündoğan',
#  'I. Perišić',
#  'S. Kagawa',
#  'R. Lewandowski',
#  'T. Inui',
#  'C. Kramer',
#  'K. Vogt',
#  'D. Ginczek',
#  'Sergio Escudero',
#  'C. Fuchs',
#  'J. Draxler',
#  'M. Höger',
#  'L. Holtby',
#  'Jurado',
#  'S. Kolašinac',
#  'J. Matip',
#  'D. Aogo',
#  'J. Bruma',
#  'D. Diekmeier',
#  'T. Rincón',
#  'J. Sala',
#  'P. Skjelbred',
#  'Son Heung-Min',
#  'R. Knoche',
#  'R. Rodríguez',
#  'M. Hasebe',
#  'M. Arnold',
#  'M. Mandžukić',
#  'G. Sio',
#  'O. Sorg',
#  'D. Caligiuri',
#  'F. Diagne',
#  'M. Ginter',
#  'J. Schmid',
#  'J. Schuster',
#  'I. Santini',
#  'Dante',
#  'H. Nordtveit',
#  'O. Wendt',
#  'P. Herrmann',
#  'M. Leckie',
#  'M. Reus',
#  'K. Rausch',
#  'L. Stindl',
#  'M. Diouf',
#  'W. Orban',
#  'S. Wagner',
#  'F. Lustenberger',
#  'Raffael',
#  'M. Plattenhardt',
#  'D. Didavi',
#  'M. Frantz',
#  'T. Chandler',
#  'S. Bell',
#  'J. Baumgartlinger',
#  'Y. Mallı',
#  'M. Risse',
#  'E. Choupo-Moting',
#  'Á. Szalai',
#  'A. Rukavina',
#  'C. Schindler',
#  'K. Volland',
#  'B. Wood',
#  'M. Lehmann',
#  'P. Schwegler',
#  'M. Weiser',
#  'M. Uth',
#  'L. Bittencourt',
#  'D. Brosinski',
#  'N. Höfler',
#  'M. Mavraj',
#  'F. Klaus',
#  'J. Haberer',
#  'H. Çalhanoğlu',
#  'P. Groß',
#  'M. Terrazzino',
#  'S. Zoller',
#  'M. Heller',
#  'B. Hübner',
#  'M. Ostrzolek',
#  'P. Verhaegh',
#  'D. Baier',
#  'Ja-Cheol Koo',
#  'A. Beck',
#  'Roberto Firmino',
#  'S. Rudy',
#  'D. Williams',
#  'A. Hahn',
#  'D. Demme',
#  'L. Rupp',
#  'M. Kruse',
#  'F. Bartels',
#  'S. Terodde',
#  'K. Kampl',
#  'E. Kachunga',
#  'D. Latza',
#  'Caiuby',
#  'C. Quaner',
#  'L. Balogun',
#  'R. Khedira',
#  'D. Heintz',
#  'J. Korb',
#  'E. Can',
#  'M. Halstenberg',
#  'J. Hofmann',
#  'J. Hector',
#  'L. Kübler',
#  'N. Schulz',
#  'M. Philipp',
#  'M. Gulde',
#  'I. Abate',
#  'Thiago Silva',
#  'M. De Sciglio',
#  'A. Aquilani',
#  'K. Boateng',
#  'B. Cristante',
#  'M. Valoti',
#  'S. El Shaarawy',
#  'Maxi López',
#  'N. Burdisso',
#  'S. Kjær',
#  'A. Rosi',
#  'José Ángel',
#  'D. De Rossi',
#  'E. Lamela',
#  'M. Pjanić',
#  'F. Viviani',
#  'F. Borini',
#  'A. Barzagli',
#  'L. Bonucci',
#  'M. Cáceres',
#  'G. Chiellini',
#  'S. Lichtsteiner',
#  'E. Giaccherini',
#  'S. Padoin',
#  'A. Vidal',
#  'A. Matri',
#  'F. Quagliarella',
#  'M. Gobbi',
#  'D. Faraoni',
#  'Juan Jesus',
#  'J. Obi',
#  'A. Poli',
#  'G. Pazzini',
#  'Ş. Radu',
#  'A. Candreva',
#  'S. Lulić',
#  'Danilo',
#  'K. Asamoah',
#  'G. Fernandes',
#  'R. Pereyra',
#  'A. Costa',
#  'S. Mustafi',
#  'Pedro Obiang',
#  'R. Soriano',
#  'F. Acerbi',
#  'M. Andreolli',
#  'D. Dainelli',
#  'P. Hetemaj',
#  'L. Rigoni',
#  'A. Paloschi',
#  'C. Théréau',
#  'A. Raggi',
#  'F. Sørensen',
#  'G. Ramírez',
#  'I. Belfodil',
#  'S. De Maio',
#  'B. Salamon',
#  'N. Tomović',
#  'A. Bertolacci',
#  'J. Cuadrado',
#  'L. Muriel',
#  'L. Rossettini',
#  'M. Destro',
#  'M. Aguirregaray',
#  'E. Muñoz',
#  'M. Silvestre',
#  'A. Acquah',
#  'A. Barberis',
#  'É. Barreto',
#  'J. Iličić',
#  'F. Vázquez',
#  'A. Masiello',
#  'F. Peluso',
#  'G. Bonaventura',
#  'L. Cigarini',
#  'E. Schelotto',
#  'M. Gabbiadini',
#  'D. Astori',
#  'N. Murru',
#  'R. Nainggolan',
#  'P. Schiattarella',
#  'L. De Silvestri',
#  'Felipe',
#  'Rômulo',
#  'V. Behrami',
#  'A. Ljajić',
#  'R. Montolivo',
#  'A. Cerci',
#  'Ryder Matos',
#  'E. Hysaj',
#  'V. Regini',
#  'R. Saponara',
#  'A. Gómez',
#  "D. D'Ambrosio",
#  'K. Glik',
#  'A. Ogbonna',
#  'M. Antenucci',
#  'S. Verdi',
#  'N. Rigoni',
#  'P. Cannavaro',
#  'F. Fernández',
#  'B. Džemaili',
#  'M. Hamšík',
#  'E. Cavani',
#  'G. Pandev',
#  'A. Belotti',
#  'M. Sampirisi',
#  'Miguel Veloso',
#  'V. Birsa',
#  'R. Palacio',
#  'Jorginho',
#  "M. D'Alessandro",
#  'M. Parolo',
#  'M. Capuano',
#  'G. Caprari',
#  'M. Verratti',
#  'C. Immobile',
#  'L. Insigne',
#  'R. Inglese',
#  'G. Donati',
#  'D. Baselli',
#  'F. Ceccherini',
#  'Gabriel Silva',
#  'I. Radovanović',
#  'G. Di Chiara',
#  'F. Cacciatore',
#  'J. Kurtič',
#  'L. Ceppitelli',
#  'A. Stoian',
#  'C. Biraghi',
#  'D. Falcinelli',
#  'M. Sau',
#  'Keko',
#  'A. Galabinov',
#  'A. Caracciolo',
#  'M. Büchel',
#  'Mário Rui',
#  'P. Iemmello',
#  'F. Magnanelli',
#  'S. Missiroli',
#  'B. Martella',
#  'S. Zaza',
#  'G. Ferrari',
#  'V. Laurini',
#  'L. Memushaj',
#  "I. M'baye",
#  'M. Benassi',
#  'Daniel Bessa',
#  'A. Duncan',
#  'A. Florenzi',
#  'G. Angella',
#  'N. Viola',
#  'A. Ragusa',
#  'F. Pisacane',
#  'L. Mora',
#  'A. Izzo',
#  'D. Zappacosta',
#  'L. Pavoletti',
#  'Diego Farias',
#  'M. Fossati',
#  'M. Coda',
#  'G. Letizia',
#  'M. Pucciarelli',
#  'B. Koné',
#  'D. Lovren',
#  'S. Umtiti',
#  'M. Zeffane',
#  'M. Gonalons',
#  'C. Grenier',
#  'A. Pléa',
#  'J. Briand',
#  'A. Lacazette',
#  'C. Jallet',
#  'B. Matuidi',
#  'J. Pastore',
#  'K. Gameiro',
#  'J. Roussillon',
#  'R. Boudebouz',
#  'S. Prcić',
#  'C. Bakambu',
#  'R. Camara',
#  'T. Monconduit',
#  'G. Mandjeck',
#  'S. Meïté',
#  'S. Haller',
#  'Y. Sanogo',
#  'K. Djidji',
#  'P. Djilobodji',
#  'J. Martins-Pereira',
#  'V. Bessat',
#  'I. Cissokho',
#  'G. Krychowiak',
#  'J. Veretout',
#  'Azpilicueta',
#  'J. Ayew',
#  'A. Ayew',
#  'L. Rémy',
#  'J. Plašil',
#  'E. Sala',
#  'T. Hazard',
#  'G. Kondogbia',
#  'D. Foulquier',
#  'K. Mangane',
#  'K. Théophile Catherine',
#  'J. Féret',
#  "Y. M'Vila",
#  'V. Pajot',
#  'S. Bahoken',
#  'M. Debuchy',
#  'F. Balmont',
#  'I. Gueye',
#  'E. Hazard',
#  'A. Soumaoro',
#  'D. Payet',
#  'R. Rodelin',
#  'N. Roux',
#  'K. Koulibaly',
#  'B. Sarr',
#  'A. Delort',
#  'S. Mané',
#  'Y. Cahuzac',
#  'F. Thauvin',
#  'W. Khazri',
#  'S. Aurier',
#  'D. Congré',
#  'S. Yago',
#  'W. Ben Yedder',
#  'E. Capoue',
#  'É. Didot',
#  'M. Sissoko',
#  'F. Tabanou',
#  'E. Rivière',
#  'B. André',
#  'P. Lasne',
#  'F. Sammaritano',
#  'Y. Andreu',
#  'F. Ghoulam',
#  'K. Zouma',
#  'M. Gradel',
#  'J. Guilavogui',
#  'L. Perrin',
#  'P. Aubameyang',
#  'F. Fajr',
#  'R. Hamouma',
#  'B. Nivet',
#  'M. Niang',
#  'J. Palmieri',
#  'N. de Préville',
#  'F. Bellugou',
#  'M. Diallo',
#  'G. Imbula',
#  'C. Kerbrat',
#  'B. Sankoh',
#  'A. Knockaert',
#  'M. Deplagne',
#  'Hilton',
#  'R. Cabella',
#  'B. Dabo',
#  'S. Camara',
#  'O. Giroud',
#  'S. Falette',
#  'C. Doukouré',
#  'K. Monnet-Paquet',
#  'J. Martin',
#  'H. Bazile',
#  'I. Traoré',
#  'N. Sliti',
#  'S. Sané',
#  'T. Mangani',
#  'B. Jeannot',
#  'P. Gouano',
#  'M. Le Marchand',
#  'J. Rivierez',
#  'R. Mahrez',
#  'C. Beauvue',
#  'D. Sidibé',
#  'V. Manceau',
#  'N. Pallois',
#  'A. Gonçalves',
#  'A. Mandi',
#  'R. Amalfitano',
#  'L. Deaux',
#  'I. Saadi',
#  'P. Baysse',
#  'A. Bamba',
#  'S. Souprayen',
#  'B. Corgnet',
#  'G. Kakuta',
#  'Y. Sankharé',
#  'J. Cordoval',
#  'G. Bong',
#  'K. Lala',
#  'A. Masuaku',
#  'R. Cohade',
#  'M. Dossevi',
#  'C. Sánchez',
#  'R. Genevois',
#  'P. Oniangué',
#  'J. Blayac',
#  'Y. Salibur',
#  'D. Sakho',
#  'A. Souquet',
#  'K. Toko Ekambi',
#  'D. Wass',
#  'M. Poundjé',
#  'N. Benezet',
#  'Júlio Tavares',
#  'P. Capelle',
#  'G. Laborde',
#  'T. Pellenard',
#  'N. Fekir',
#  'R. Ghezzal',
#  'Y. Benzia',
#  "C. N'Jie",
#  'A. Tameze',
#  'I. Amadou',
#  'T. Bakayoko',
#  'A. Doucouré',
#  'R. Aguilar',
#  'J. Ikoko',
#  'Y. Sabaly',
#  'K. Azamoum',
#  'F. Guilbert',
#  'T. Lemar',
#  'O. Nguette',
#  'D. Liénard',
#  'J. Giraudon',
#  'R. Thomas',
#  'E. Seka',
#  'P. Martinez',
#  'M. Lemina',
#  'B. Pelé',
#  'F. Chafik',
#  'O. El Hajjam',
#  'J. Marié',
#  'F. Mollet',
#  'N. Kanté',
#  'Sidnei',
#  'C. Tosun',
#  'E. Çolak',
#  'P. Pekarík',
#  'N. Amrabat',
#  'C. Kouyaté',
#  'L. Biglia',
#  'D. Praet',
#  'J. Lukaku',
#  'T. Meunier',
#  'C. Bacca',
#  'A. Finnbogason',
#  'S. Peeters',
#  'K. De Bruyne',
#  'C. Benteke',
#  'D. Opare',
#  'M. Batshuayi',
#  'S. Gakpé',
#  'L. Depoitre',
#  'E. Zukanović',
#  'Lucas Lima',
#  'Leandro Castán',
#  'Marquinhos',
#  'Paulinho',
#  'Guilherme',
#  'Wendell',
#  'Allan',
#  'Casemiro',
#  'Willian José',
#  'Felipe Anderson',
#  'Neymar',
#  'Rafael Tolói',
#  'Thiago Mendes',
#  'M. Lanzini',
#  'Gabriel',
#  'Somália',
#  'Andrei Girotto',
#  'Bruno Peres',
#  'D. Abraham',
#  'A. Ajeti',
#  'X. Shaqiri',
#  'G. Xhaka',
#  'F. Moubandje',
#  'M. Bauer',
#  'R. Freuler',
#  'S. Zuber',
#  'B. Djimsiti',
#  'S. Widmer',
#  'A. Ioniţă',
#  'F. Schär',
#  'F. Helander',
#  'J. Durmaz',
#  'C. Borges',
#  'R. Quaison',
#  'E. Krafth',
#  'E. Forsberg',
#  'O. Hiljemark',
#  'M. Rohdén',
#  'L. Augustinsson',
#  'O. Selnæs',
#  'M. Braithwaite',
#  'M. Jørgensen',
#  'T. Delaney',
#  'R. Durmisi',
#  'M. Krohn-Dehli',
#  'J. Stryger Larsen',
#  'Y. Poulsen',
#  'L. Lerager',
#  'G. Cameron',
#  'Sung-Yeung Ki',
#  'V. Wanyama',
#  'S. Davis',
#  'R. Fraser',
#  'A. Mooy',
#  'M. Suttner',
#  'G. Burgstaller',
#  'S. Ilsanker',
#  'F. Kainz',
#  'M. Hinteregger',
#  'M. Gregoritsch',
#  'K. Wimmer',
#  'M. Sabitzer',
#  'C. Kabasele',
#  'M. Badelj',
#  'M. Kovačić',
#  'Š. Vrsaljko',
#  'A. Kramarić',
#  'A. Budimir',
#  'M. Pavlović',
#  'A. Rebić',
#  'M. Brozović',
#  'Alex Sandro',
#  'N. Otamendi',
#  'S. Defour',
#  'João Moutinho',
#  'J. Rodríguez',
#  'E. Garay',
#  'N. Matić',
#  'Nolito',
#  'Rodrigo',
#  'E. Insúa',
#  'A. Carrillo',
#  'C. Atsu',
#  'Cédric Soares',
#  'Luisinho',
#  'Paulo Oliveira',
#  'Mexer',
#  'Edgar Ié',
#  'João Mário',
#  'Bruma',
#  'Marçal',
#  'V. Lindelöf',
#  'Simy',
#  'A. Williams',
#  'J. Allen',
#  'N. Dyer',
#  'G. Sigurðsson',
#  'T. Gebre Selassie',
#  'P. Kadeřábek',
#  'V. Darida',
#  'A. Maxim',
#  'A. Toșca',
#  'R. Berič',
#  'F. Roncaglia',
#  'G. Mercado',
#  'D. Zapata',
#  'L. Castro',
#  'B. Zuculini',
#  'G. Pezzella',
#  'L. Ocampos',
#  'J. Palomino',
#  'G. Poblete',
#  'L. Alario',
#  'P. De Blasis',
#  'M. Dos Santos',
#  'G. Pizarro',
#  'P. Dybala',
#  'C. Aránguiz',
#  'E. Pulgar',
#  ...]

# %%
os.path.abspath(os.path.join('Wyscout','final_results_allplayers.h5'))
# Out:
# 'e:\\MLWorkspace\\player2vec\\Wyscout\\final_results_allplayers.h5'

# %%
filepath=os.path.abspath(os.path.join('Wyscout','final_results_allplayers.h5'))
temp_df=pd.read_hdf(filepath,'all_players')
temp_df.head(2)
# Out:
#    player_ids                                         player_hms  \
# 0          36  [0.27780113, 0.35005432, 0.28585786, 0.3413276...
# 1          48  [0.27780113, 0.35005432, 0.28641888, 0.3406051...
#
#                                      player_features  \
# 0  [1.0, 0.0, 0.2619311875693674, 0.7380688124306...
# 1  [1.0, 0.0, 0.16969185310257492, 0.830308146897...
#
#                                              all_hms  \
# 0  [0.0, 0.6224079096751817, 0.5278657970115652, ...
# 1  [0.6231349144023873, 0.0, 0.6171921896078022, ...
#
#                                      all_subfeatures  \
# 0  [0.0, 0.16845717510983493, 0.45865277873455934...
# 1  [0.15852097506385526, 0.0, 0.4884224007129867,...
#
#                                         all_features  \
# 0  [0.0, 0.7908650847850166, 0.9865185757461246, ...
# 1  [0.7816558894662426, 0.0, 1.1056145903207888, ...
#
#                                            top20_ids  \
# 0  [36, 3526, 14991, 7855, 14716, 14687, 86328, 2...
# 1  [48, 134502, 77, 393228, 3306, 20866, 213308, ...
#
#                                          top10_names  player_id  \
# 0  [T. Alderweireld, M. Musacchio, M. Ginter, L. ...         36
# 1  [J. Vertonghen, A. Laporte, N. Moisander, M. S...         48
#
#        player_name
# 0  T. Alderweireld
# 1    J. Vertonghen

# %%
temp_df['player_name'].unique()
# Out:
# array(['T. Alderweireld', 'J. Vertonghen', 'C. Eriksen', ...,
#        'W. McKennie', 'Martín', 'I. Niane'], dtype=object)
